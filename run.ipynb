# %%
# !/home/ubuntu/anaconda3/envs/pytorch_p36/bin/python train.py --cuda\
-distance 1 \
-cVa 20 \
-nsTr 1 \
-nsVa 1 \
-nep 30 \
-its 150
# Out:
# Namespace(classes_per_it_tr=60, classes_per_it_val=20, cuda=True, dataset_root='../dataset', distance_fn=1, epochs=30, experiment_root='../output', iterations=150, learning_rate=0.001, lr_scheduler_gamma=0.5, lr_scheduler_step=20, manual_seed=7, net=1, num_query_tr=5, num_query_val=15, num_support_tr=1, num_support_val=1)
# == Dataset: Found 82240 items
# == Dataset: Found 4112 classes
# == Dataset: Found 13760 items
# == Dataset: Found 688 classes
# == Dataset: Found 33840 items
# == Dataset: Found 1692 classes
# === Epoch: 0 ===
# 100%|█████████████████████████████████████████| 150/150 [00:06<00:00, 21.83it/s]
# Avg Train Loss: 1.4606632995605469, Avg Train Acc: 0.6260666674375535
# Avg Val Loss: 0.5661936334768931, Avg Val Acc: 0.8190666671593984 (Best)
# === Epoch: 1 ===
# 100%|█████████████████████████████████████████| 150/150 [00:06<00:00, 22.64it/s]
# Avg Train Loss: 0.6820031787951787, Avg Train Acc: 0.8016888880729676
# ...

# %%
# !/home/ubuntu/anaconda3/envs/pytorch_p36/bin/python train_miniImageNet.py --cuda -distance 1 -cVa 5 -nsTr 1 -nsVa 1 -nep 30 -its 150
# Out:
# === Epoch: 0 ===
# 100%|█████████████████████████████████████████| 150/150 [05:39<00:00,  2.26s/it]
# Avg Train Loss: 38.06968114217123, Avg Train Acc: 0.04542222232868274
# Avg Val Loss: 1.9788398591677347, Avg Val Acc: 0.2678222237030665 (Best)
# === Epoch: 1 ===
# 100%|█████████████████████████████████████████| 150/150 [05:38<00:00,  2.26s/it]
# Avg Train Loss: 4.275692027409871, Avg Train Acc: 0.04620000007251898
# Avg Val Loss: 1.6961043691635131, Avg Val Acc: 0.28462222253282865 (Best)
# === Epoch: 2 ===
# 100%|█████████████████████████████████████████| 150/150 [05:38<00:00,  2.26s/it]
# Avg Train Loss: 4.086460296312968, Avg Train Acc: 0.05277777804682652
# Avg Val Loss: 1.6098406449953715, Avg Val Acc: 0.30471111223101616 (Best)
# === Epoch: 3 ===
# 100%|█████████████████████████████████████████| 150/150 [05:36<00:00,  2.24s/it]
# Avg Train Loss: 4.01810140768687, Avg Train Acc: 0.05526666719466448
# Avg Val Loss: 1.5949336949984232, Avg Val Acc: 0.3080888910094897 (Best)
# ...
